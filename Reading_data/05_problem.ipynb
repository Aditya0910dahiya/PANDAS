# %% [markdown]
# # 1- cloumn, rows?
# # 2-what type of?
# # 3- missing data?
#
# # info()
# # methods
#
# # 1-number of rows and cloumns
# # 2-column name
# # 3-int64 float64 object
# # 5-memory usage of the data frame

# %%
import pandas as pd

data=pd.read_json("sample_Data.json")

print("display the info of the data set")
print(data.info())
# Out:
# display the info of the data set
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           20 non-null     int64
#  1   name         20 non-null     str
#  2   description  20 non-null     str
#  3   price        20 non-null     float64
#  4   category     20 non-null     str
#  5   image        20 non-null     str
# dtypes: float64(1), int64(1), str(4)
# memory usage: 1.1 KB
# None

# %%
data={"name":["raam","shyam","ghanshyam"],
      "age":[10,20,30],
      "city":["nagpur","mumbai","delhi"]
}
data_frame=pd.DataFrame(data)

print("display the info of the data set")
print(data_frame.info())

# in this we use info to sammerise our data set
# info ka use karke han memory use check kar sakte hai
# we can also check datatype
# Out:
# display the info of the data set
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      str
#  1   age     3 non-null      int64
#  2   city    3 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 204.0 bytes
# None
